# %%
Hands on with pandas?
Artwork.csv =>This datset is having artwork of various artists…!?
Pandas is built on top of numpy so always we have to import both while writing any pandas program

# %%
File ext or file format -----! =>.CSV (comma seperated value)

# %%
import numpy as np
import pandas as pd

# %%
how to read the data in pandas?

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('artwork_data.csv')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
Step 1:- cleansing the data

# %%
req:-
    1.to use the id of the dataset only
    2.to display on the top 5 rows

# %%
df = pd.read_csv('artwork_data.csv', nrows = 5,index_col = 'id')

df
# Out:
#      accession_number          artist artistRole  artistId  \
# id
# 1035           A00001   Blake, Robert     artist        38
# 1036           A00002   Blake, Robert     artist        38
# 1037           A00003   Blake, Robert     artist        38
# 1038           A00004   Blake, Robert     artist        38
# 1039           A00005  Blake, William     artist        39
#
#                                                   title  \
# id
# 1035  A Figure Bowing before a Seated Old Man with h...
# 1036  Two Drawings of Frightened Figures, Probably f...
# 1037  The Preaching of Warning. Verso: An Old Man En...
# 1038     Six Drawings of Figures with Outstretched Arms
# 1039  The Circle of the Lustful: Francesca da Rimini...
#
#                     dateText  \
# id
# 1035          date not known
# 1036          date not known
# 1037                 ?c.1785
# 1038          date not known
# 1039  1826–7, reprinted 1892
#
#                                                  medium  \
# id
# ...

# %%
req: to get the cols =>id,artist,title

# %%
df = pd.read_csv('artwork_data.csv',nrows = 5,index_col ='id',usecols=['id','artist','title'])

df
# Out:
#               artist                                              title
# id
# 1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...

# %%
req: adding more cols as per the req of the client

# %%
COLS_TO_USE =['id','artist','title','medium','year','height','width']

# %%
df = pd.read_csv('artwork_data.csv',nrows=5,index_col='id',usecols = COLS_TO_USE)

df
# Out:
#               artist                                              title  \
# id
# 1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#                                                  medium    year  width  height
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     NaN    394     419
# 1036                                  Graphite on paper     NaN    311     213
# 1037        Graphite on paper. Verso: graphite on paper  1785.0    343     467
# 1038                                  Graphite on paper     NaN    318     394
# 1039                            Line engraving on paper  1826.0    243     335

# %%
#We can save the data use below command:-

# %%
df.to_pickle('dataframe_h.pickle')

# %%
python follows by default a pickle serelisation...! #compression technique of the data....!

# %%
x = pd.read_pickle('dataframe_h.pickle')

x
# Out:
#               artist                                              title  \
# id
# 1035   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039  Blake, William  The Circle of the Lustful: Francesca da Rimini...
#
#                                                  medium    year  width  height
# id
# 1035  Watercolour, ink, chalk and graphite on paper....     NaN    394     419
# 1036                                  Graphite on paper     NaN    311     213
# 1037        Graphite on paper. Verso: graphite on paper  1785.0    343     467
# 1038                                  Graphite on paper     NaN    318     394
# 1039                            Line engraving on paper  1826.0    243     335

# %%
Continution with pandas

# %%
df = pd.read_csv('artwork_data.csv',index_col='id')

df
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        accession_number              artist artistRole  artistId  \
# id
# 1035             A00001       Blake, Robert     artist        38
# 1036             A00002       Blake, Robert     artist        38
# 1037             A00003       Blake, Robert     artist        38
# 1038             A00004       Blake, Robert     artist        38
# 1039             A00005      Blake, William     artist        39
# ...                 ...                 ...        ...       ...
# 122960           T13865  P-Orridge, Genesis     artist     16646
# 122961           T13866  P-Orridge, Genesis     artist     16646
# 121181           T13867        Hatoum, Mona     artist      2365
# 112306           T13868       Creed, Martin     artist      2760
# ...

# %%
req 1: we want to know how many distinct artists are there in the dataset available to us ....?
    
req 2:how many?

req 3:i want to know the no of persons..?

# %%
artists = df['artist'] #Loading total artist in the dataset

pd.unique(artists) #Unique artists =>In the dataset

len(pd.unique(artists)) #It is calaculating the no of elements in the dataset
# Out:
# 3336

# %%
req:- i wanted to know 'Bacon , Francis' how many artwork submitted...?

# %%
s = df['artist'] == 'Bacon, Francis' #50 submission of his artwork in the gallery

s.value_counts()
# Out:
# False    69151
# True        50
# Name: artist, dtype: int64

# %%
second approach same for the above scenario

# %%
artist_counts = df['artist'].value_counts()

artist_counts
# Out:
# Turner, Joseph Mallord William    39389
# Jones, George                      1046
# Moore, Henry, OM, CH                623
# Daniell, William                    612
# Beuys, Joseph                       578
#                                   ...
# Somerscales, Thomas J.                1
# Boys, Thomas Shotter                  1
# Celic, Stojan                         1
# Muñoz, Óscar                          1
# Butler, Elizabeth                     1
# Name: artist, Length: 3336, dtype: int64
