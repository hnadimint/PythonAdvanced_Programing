# %%
Intro duction to Matplotlib ==>Visualization libarary
    
numpy ========>pandas ========>matplotlib

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
z= [10,5,0]

plt.plot(x,y)
plt.plot(x,z)
plt.xlabel('x-axis')
plt.ylabel('y and z axis')
plt.title('test graph')
plt.legend(["this is x and y" , "this is x and z"])
plt.show()

# %%
plt.title('sales information')

x = [1,2,3]
y = [1,4,9]
z = [10,5,0]


plt.xlabel('x-axis')
plt.ylabel('y and z axis')
plt.title('test graph')
plt.legend(["this is x and y" , "this is x and z"])
plt.show()

# %%
understanding the countries.csv file : 
    
    population information of across the globe ...we are havinf the info ...! 5 years of each country.

# %%
data = pd.read_csv('countries.csv')

data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
getting the solution:-
    
Step1 : Getting the us data out of the main data file.

# %%
us = data[data.country == 'United States']

us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
ch = data[data.country == 'China']

ch
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year,us.population/10**6)
plt.plot(ch.year,ch.population/10**6)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparision')
plt.legend(['united states' , 'China'])
plt.show()

# %%
China and us

10 countries comparies =>each graph you will be having 2 countries
5 graphs i need to see ,that your assignment today.

# %%
af = data[data.country == 'Afghanistan']

af
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
al = data[data.country == 'Albania']

al
# Out:
#     country  year  population
# 12  Albania  1952     1282697
# 13  Albania  1957     1476505
# 14  Albania  1962     1728137
# 15  Albania  1967     1984060
# 16  Albania  1972     2263554
# 17  Albania  1977     2509048
# 18  Albania  1982     2780097
# 19  Albania  1987     3075321
# 20  Albania  1992     3326498
# 21  Albania  1997     3428038
# 22  Albania  2002     3508512
# 23  Albania  2007     3600523

# %%
plt.plot(af.year,af.population/10**6)
plt.plot(al.year,al.population/10**6)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparision')
plt.legend(['Afghanistan' , 'Albaniaa'])
plt.show()

# %%
Australia = data[data.country == 'Australia']

Australia
# Out:
#       country  year  population
# 60  Australia  1952     8691212
# 61  Australia  1957     9712569
# 62  Australia  1962    10794968
# 63  Australia  1967    11872264
# 64  Australia  1972    13177000
# 65  Australia  1977    14074100
# 66  Australia  1982    15184200
# 67  Australia  1987    16257249
# 68  Australia  1992    17481977
# 69  Australia  1997    18565243
# 70  Australia  2002    19546792
# 71  Australia  2007    20434176

# %%
Bahrain = data[data.country == 'Bahrain']

Bahrain
# Out:
#     country  year  population
# 84  Bahrain  1952      120447
# 85  Bahrain  1957      138655
# 86  Bahrain  1962      171863
# 87  Bahrain  1967      202182
# 88  Bahrain  1972      230800
# 89  Bahrain  1977      297410
# 90  Bahrain  1982      377967
# 91  Bahrain  1987      454612
# 92  Bahrain  1992      529491
# 93  Bahrain  1997      598561
# 94  Bahrain  2002      656397
# 95  Bahrain  2007      708573

# %%
plt.plot(Australia.year,Australia.population/10**6)
plt.plot(Bahrain.year,Bahrain.population/10**6)
plt.xlabel('year')
plt.ylabel('population')
plt.title('population growth comparision')
plt.legend(['Afghanistan' , 'Albaniaa'])
plt.show()

# %%
IQ’s:-
=>Expalin Numpy and Datatypes?
=>Expain btwn nd editor and pattern??
Cloumn based flattening editing =>order = f
=>Diff betwn deep copy and shallow copy?
=>What is pandas and what is the datatypes?
=>what is custom datatype??
 
 
 
=>What is the use of matlotlib?
=> 
05/06/2020
